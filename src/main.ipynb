# %% [markdown]
# # House Price Prediction🏡

# %%
# Installing Libraries
! pip install pandas
! pip install numpy
! pip install matplotlib
! pip install seaborn
# Out:
# Requirement already satisfied: pandas in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy<2,>=1.26.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (1.26.1)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/d9/82/59970be41cc28cd7b7ae3ddc1d6b3891715af669ea0a0d2c244e126d3bb6/matplotlib-3.8.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/75/d4/c3b7a9a0d1f99b528e5a46266b0b9f13aad5a0dd1156d071418df314c427/contourpy-1.1.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached contourpy-1.1.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/24/01/9bb5e115206b5c7f7894978f9af57a3d17c94fbc0df913389f1eaf334a68/fonttools-4.43.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached fonttools-4.43.1-cp312-cp312-win_amd64.whl.metadata (155 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/63/50/2746566bdf4a6a842d117367d05c90cfb87ac04e9e2845aa1fa21f071362/kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata
#   Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/32/e4/978865107d097dd9cb650331676d8dc29ed9fcd0aaab46486e9d6e5123f0/Pillow-10.1.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached Pillow-10.1.0-cp312-cp312-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl.metadata
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.1-cp312-cp312-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB 330.3 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/7.6 MB 409.6 kB/s eta 0:00:19
#     --------------------------------------- 0.1/7.6 MB 602.4 kB/s eta 0:00:13
#    - -------------------------------------- 0.2/7.6 MB 919.0 kB/s eta 0:00:09
#    - -------------------------------------- 0.3/7.6 MB 1.1 MB/s eta 0:00:07
#    -- ------------------------------------- 0.4/7.6 MB 1.2 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/7.6 MB 1.4 MB/s eta 0:00:05
#    --- ------------------------------------ 0.6/7.6 MB 1.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.6 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.9/7.6 MB 1.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.1/7.6 MB 1.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.2/7.6 MB 1.8 MB/s eta 0:00:04
#    ------ --------------------------------- 1.3/7.6 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.4/7.6 MB 2.0 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.6 MB 2.0 MB/s eta 0:00:03
#    -------- ------------------------------- 1.7/7.6 MB 2.0 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/7.6 MB 2.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.9/7.6 MB 2.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.0/7.6 MB 2.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.2/7.6 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.3/7.6 MB 2.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.4/7.6 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.5/7.6 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.7/7.6 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.7/7.6 MB 2.2 MB/s eta 0:00:03
#    -------------- ------------------------- 2.8/7.6 MB 2.2 MB/s eta 0:00:03
#    --------------- ------------------------ 3.0/7.6 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.1/7.6 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.2/7.6 MB 2.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.3/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.5/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.6/7.6 MB 2.3 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.6 MB 2.3 MB/s eta 0:00:02
#    -------------------- ------------------- 3.9/7.6 MB 2.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.0/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 4.1/7.6 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.3/7.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.4/7.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.6/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 4.7/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 4.8/7.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 4.9/7.6 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 5.0/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.2/7.6 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.3/7.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.4/7.6 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.7/7.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 5.8/7.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.9/7.6 MB 2.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.0/7.6 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.2/7.6 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.3/7.6 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 6.4/7.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.5/7.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.7/7.6 MB 2.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.1/7.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.2/7.6 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 2.5 MB/s eta 0:00:00
# Using cached contourpy-1.1.1-cp312-cp312-win_amd64.whl (486 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.43.1-cp312-cp312-win_amd64.whl (2.1 MB)
# Using cached kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
# Using cached Pillow-10.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 kiwisolver-1.4.5 matplotlib-3.8.1 pillow-10.1.0 pyparsing-3.1.1
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: pandas>=1.2 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from seaborn) (3.8.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 262.6 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.6 kB 245.8 kB/s eta 0:00:02
#    --------------- ---------------------- 122.9/294.6 kB 599.1 kB/s eta 0:00:01
#    -------------------------- ----------- 204.8/294.6 kB 827.9 kB/s eta 0:00:01
#    ---------------------------------------- 294.6/294.6 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Data Setup and Analysis

# %%
# Importing Libraries in to the notebook 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./data/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# Removing the rows null values
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
! pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/fe/6b/db949ed5ac367987b1f250f070f340b7715d22f0c9c965bdf07de6ca75a3/scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata
#   Using cached scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.5.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from scikit-learn) (1.11.3)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\debarshee\projects\09_house_price_prediction\env\lib\site-packages (from scikit-learn) (3.2.0)
# Using cached scikit_learn-1.3.2-cp312-cp312-win_amd64.whl (9.1 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
# Dividing the data in to train and test data
x = data.drop(["median_house_value"], axis=1)
y = data["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7603     -118.24     33.88                37.0       1843.0           366.0
# 10019    -121.18     39.19                16.0       1528.0           351.0
# 12664    -121.45     38.49                34.0       3573.0           662.0
# 12250    -116.98     33.77                12.0       5829.0          1309.0
# 15071    -116.98     32.79                32.0       3756.0           662.0
# ...          ...       ...                 ...          ...             ...
# 2513     -122.18     39.75                30.0       4157.0           834.0
# 12538    -121.49     38.56                52.0       1844.0           392.0
# 16155    -122.49     37.78                47.0       2695.0           643.0
# 3992     -118.64     34.17                26.0       6767.0           903.0
# 9908     -122.30     38.32                20.0       2063.0           486.0
#
#        population  households  median_income ocean_proximity  \
# 7603       1207.0       351.0         2.4821       <1H OCEAN
# 10019       729.0       319.0         2.4688          INLAND
# 12664      1540.0       620.0         3.5323          INLAND
# 12250      2711.0      1118.0         1.9707          INLAND
# 15071      1611.0       598.0         3.8667       <1H OCEAN
# ...           ...         ...            ...             ...
# 2513       1885.0       774.0         1.6948          INLAND
# 12538       667.0       353.0         3.0033          INLAND
# 16155      1505.0       644.0         3.0877        NEAR BAY
# 3992       2574.0       883.0         7.7846       <1H OCEAN
# 9908       1045.0       460.0         2.5035        NEAR BAY
#
#        median_house_value
# 7603             111000.0
# 10019            138800.0
# 12664            109800.0
# 12250            107900.0
# 15071            189700.0
# ...                   ...
# 2513              67500.0
# 12538            103500.0
# 16155            329100.0
# 3992             409000.0
# 9908             153200.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(16,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
dis_train_data = train_data.drop('ocean_proximity', axis=1)
correlation_matrix = dis_train_data.corr()

# %%
correlation_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924974           -0.112743     0.047221
# latitude            -0.924974  1.000000            0.015565    -0.037885
# housing_median_age  -0.112743  0.015565            1.000000    -0.362067
# total_rooms          0.047221 -0.037885           -0.362067     1.000000
# total_bedrooms       0.072521 -0.068652           -0.323669     0.930651
# population           0.099595 -0.107188           -0.296217     0.856150
# households           0.059073 -0.073332           -0.305548     0.920266
# median_income       -0.017092 -0.078283           -0.116639     0.197992
# median_house_value  -0.044928 -0.145450            0.108002     0.135111
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072521    0.099595    0.059073      -0.017092
# latitude                 -0.068652   -0.107188   -0.073332      -0.078283
# housing_median_age       -0.323669   -0.296217   -0.305548      -0.116639
# total_rooms               0.930651    0.856150    0.920266       0.197992
# total_bedrooms            1.000000    0.876364    0.979882      -0.007774
# population                0.876364    1.000000    0.905474       0.004863
# households                0.979882    0.905474    1.000000       0.013960
# median_income            -0.007774    0.004863    0.013960       1.000000
# median_house_value        0.050541   -0.023356    0.066167       0.687233
#
#                     median_house_value
# longitude                    -0.044928
# latitude                     -0.145450
# housing_median_age            0.108002
# total_rooms                   0.135111
# total_bedrooms                0.050541
# population                   -0.023356
# households                    0.066167
# median_income                 0.687233
# median_house_value            1.000000

# %%
plt.figure(figsize=(16,8))
sns.heatmap(dis_train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# ## Preprocessing the Data

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] + 1)
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] + 1)
train_data["population"] = np.log(train_data["population"] + 1)
train_data["households"] = np.log(train_data["households"] + 1)

# %%
train_data.hist(figsize=(16,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
dis_train_data = train_data.drop('ocean_proximity', axis=1)
correlation_matrix = dis_train_data.corr()

# %%
correlation_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924974           -0.112743     0.033222
# latitude            -0.924974  1.000000            0.015565    -0.033888
# housing_median_age  -0.112743  0.015565            1.000000    -0.318676
# total_rooms          0.033222 -0.033888           -0.318676     1.000000
# total_bedrooms       0.065663 -0.070796           -0.277448     0.945754
# population           0.113960 -0.137755           -0.250149     0.863794
# households           0.061566 -0.090819           -0.248336     0.932270
# median_income       -0.017092 -0.078283           -0.116639     0.201076
# median_house_value  -0.044928 -0.145450            0.108002     0.159699
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.065663    0.113960    0.061566      -0.017092
# latitude                 -0.070796   -0.137755   -0.090819      -0.078283
# housing_median_age       -0.277448   -0.250149   -0.248336      -0.116639
# total_rooms               0.945754    0.863794    0.932270       0.201076
# total_bedrooms            1.000000    0.896733    0.975309      -0.030802
# population                0.896733    1.000000    0.930124      -0.010749
# households                0.975309    0.930124    1.000000      -0.001216
# median_income            -0.030802   -0.010749   -0.001216       1.000000
# median_house_value        0.054840   -0.022138    0.073969       0.687233
#
#                     median_house_value
# longitude                    -0.044928
# latitude                     -0.145450
# housing_median_age            0.108002
# total_rooms                   0.159699
# total_bedrooms                0.054840
# population                   -0.022138
# households                    0.073969
# median_income                 0.687233
# median_house_value            1.000000

# %%
plt.figure(figsize=(16,8))
sns.heatmap(dis_train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# While building a model its hard to work with non-numerical data.
# So we need to convert them into numerical values.
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7185
# INLAND        5256
# NEAR OCEAN    2089
# NEAR BAY      1812
# ISLAND           4
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 7603        True   False   False     False       False
# 10019      False    True   False     False       False
# 12664      False    True   False     False       False
# 12250      False    True   False     False       False
# 15071       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 2513       False    True   False     False       False
# 12538      False    True   False     False       False
# 16155      False   False   False      True       False
# 3992        True   False   False     False       False
# 9908       False   False   False      True       False
#
# [16346 rows x 5 columns]

# %%
# train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop('ocean_proximity', axis=1)

# Create one-hot encoded columns for 'ocean_proximity'
dummies = pd.get_dummies(train_data['ocean_proximity'])

# Replace True/False with 1/0
dummies = dummies.astype(int)

# Join the one-hot encoded columns to your DataFrame
train_data = train_data.join(dummies)

# Drop the original 'ocean_proximity' column
train_data = train_data.drop('ocean_proximity', axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7603     -118.24     33.88                37.0     7.519692        5.905362
# 10019    -121.18     39.19                16.0     7.332369        5.863631
# 12664    -121.45     38.49                34.0     8.181441        6.496775
# 12250    -116.98     33.77                12.0     8.670772        7.177782
# 15071    -116.98     32.79                32.0     8.231376        6.496775
# ...          ...       ...                 ...          ...             ...
# 2513     -122.18     39.75                30.0     8.332789        6.727432
# 12538    -121.49     38.56                52.0     7.520235        5.973810
# 16155    -122.49     37.78                47.0     7.899524        6.467699
# 3992     -118.64     34.17                26.0     8.819961        6.806829
# 9908     -122.30     38.32                20.0     7.632401        6.188264
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7603     7.096721    5.863631         2.4821            111000.0          1
# 10019    6.593045    5.768321         2.4688            138800.0          0
# 12664    7.340187    6.431331         3.5323            109800.0          0
# 12250    7.905442    7.020191         1.9707            107900.0          0
# 15071    7.385231    6.395262         3.8667            189700.0          1
# ...           ...         ...            ...                 ...        ...
# 2513     7.542213    6.652863         1.6948             67500.0          0
# 12538    6.504288    5.869297         3.0033            103500.0          0
# 16155    7.317212    6.469250         3.0877            329100.0          0
# 3992     7.853605    6.784457         7.7846            409000.0          1
# 9908     6.952729    6.133398         2.5035            153200.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 7603        0       0         0           0
# 10019       1       0         0           0
# 12664       1       0         0           0
# 12250       1       0         0           0
# 15071       0       0         0           0
# ...       ...     ...       ...         ...
# 2513        1       0         0           0
# 12538       1       0         0           0
# 16155       0       0         1           0
# 3992        0       0         0           0
# 9908        0       0         1           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(16,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>
